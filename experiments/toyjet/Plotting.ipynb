# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import corner
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
#
import sys
sys.path.append('../../')
import data.datasets as datasets
import data.data_utils as dutils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file=np.load("model_disc4_rand1_seed1maha_toys_space.npz")

plt.plot(file["toyxy"],file["toymc"]   ,c='b',label="Trained MC")
plt.plot(file["toyxy"],file["toydata"] ,c='b',label="Data",linestyle="dashed")
plt.plot(file["toyxy"],file["toyrawmc"],c='r',label="Raw MC")
plt.plot(file["toyxy"],file["toyrawdata"],c='r',label="Raw Data",linestyle="dashed")
plt.xlabel("yield")
plt.ylabel("z-score")
plt.legend()
plt.show()

# %%
import utils.plotting as utils

utils.make_corner(file["mc_out"],file["mc_lab"])
utils.make_corner(file["da_out"],file["da_lab"])
